# %%
# !python --version

import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Python 3.8.5

# %%
df = pd.read_csv(r"C:\Users\William\Desktop\Capstone_Data\MPS_RTXP_2020-07-15_2020-10-14_L_LUZON.csv")

# %%
df
# Out:
#        DELIVERY_DATE  DELIVERY_HOUR REGION_ID TYPE_ID PARTICIPANT_ID  \
# 0          7/15/2020              1     LUZON      LD      1LT_T2L1T
# 1          7/15/2020              1     LUZON      LD      1LT_T2L2T
# 2          7/15/2020              1     LUZON      LD      1_PHILEXT
# 3          7/15/2020              1     LUZON      LD            AEC
# 4          7/15/2020              1     LUZON      LD          ALECO
# ...              ...            ...       ...     ...            ...
# 576283    10/14/2020             24     LUZON      LD        WESMTMP
# 576284    10/14/2020             24     LUZON      LD        WESMTMP
# 576285    10/14/2020             24     LUZON      LD        WESMTMP
# 576286    10/14/2020             24     LUZON      LD        WESMTMP
# 576287    10/14/2020             24     LUZON      LD        ZAMECO1
#
#         RESOURCE_ID    MW    PRICE
# 0       1LATRI_T2L1   6.7  2084.01
# 1       1LATRI_T2L2  15.8  2084.01
# 2       1LAT_PHILEX  33.0  2084.01
# 3          1MEX_AEC   0.0  2101.26
# 4        3DAR_ALECO  34.0  2022.11
# ...             ...   ...      ...
# 576283   3LABO_T1L2   3.8     1.00
# 576284     3LUZ_001   0.0     1.00
# 576285  3MAKBA_T3L2  37.4     1.00
# 576286  3MLAYA_T2L2   0.0     1.01
# 576287  1BOTOL_T1L1   3.3     1.00
#
# [576288 rows x 8 columns]

# %%
df_orig = df.copy()

# %%
df_orig
# Out:
#        DELIVERY_DATE  DELIVERY_HOUR REGION_ID TYPE_ID PARTICIPANT_ID  \
# 0          7/15/2020              1     LUZON      LD      1LT_T2L1T
# 1          7/15/2020              1     LUZON      LD      1LT_T2L2T
# 2          7/15/2020              1     LUZON      LD      1_PHILEXT
# 3          7/15/2020              1     LUZON      LD            AEC
# 4          7/15/2020              1     LUZON      LD          ALECO
# ...              ...            ...       ...     ...            ...
# 576283    10/14/2020             24     LUZON      LD        WESMTMP
# 576284    10/14/2020             24     LUZON      LD        WESMTMP
# 576285    10/14/2020             24     LUZON      LD        WESMTMP
# 576286    10/14/2020             24     LUZON      LD        WESMTMP
# 576287    10/14/2020             24     LUZON      LD        ZAMECO1
#
#         RESOURCE_ID    MW    PRICE
# 0       1LATRI_T2L1   6.7  2084.01
# 1       1LATRI_T2L2  15.8  2084.01
# 2       1LAT_PHILEX  33.0  2084.01
# 3          1MEX_AEC   0.0  2101.26
# 4        3DAR_ALECO  34.0  2022.11
# ...             ...   ...      ...
# 576283   3LABO_T1L2   3.8     1.00
# 576284     3LUZ_001   0.0     1.00
# 576285  3MAKBA_T3L2  37.4     1.00
# 576286  3MLAYA_T2L2   0.0     1.01
# 576287  1BOTOL_T1L1   3.3     1.00
#
# [576288 rows x 8 columns]

# %%
df = df.drop(columns=['REGION_ID', 'TYPE_ID'])

# %%
df
# Out:
#        DELIVERY_DATE  DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW    PRICE
# 0          7/15/2020              1      1LT_T2L1T  1LATRI_T2L1   6.7  2084.01
# 1          7/15/2020              1      1LT_T2L2T  1LATRI_T2L2  15.8  2084.01
# 2          7/15/2020              1      1_PHILEXT  1LAT_PHILEX  33.0  2084.01
# 3          7/15/2020              1            AEC     1MEX_AEC   0.0  2101.26
# 4          7/15/2020              1          ALECO   3DAR_ALECO  34.0  2022.11
# ...              ...            ...            ...          ...   ...      ...
# 576283    10/14/2020             24        WESMTMP   3LABO_T1L2   3.8     1.00
# 576284    10/14/2020             24        WESMTMP     3LUZ_001   0.0     1.00
# 576285    10/14/2020             24        WESMTMP  3MAKBA_T3L2  37.4     1.00
# 576286    10/14/2020             24        WESMTMP  3MLAYA_T2L2   0.0     1.01
# 576287    10/14/2020             24        ZAMECO1  1BOTOL_T1L1   3.3     1.00
#
# [576288 rows x 6 columns]

# %%
df['DELIVERY_HOUR'] = df['DELIVERY_HOUR'].apply(lambda x: int(x-1))

# %%
df['DELIVERY_HOUR'] = df['DELIVERY_HOUR'].astype('str').apply(lambda x: dt.datetime.strptime(x, '%H'))

# %%
df['DELIVERY_HOUR'] = df['DELIVERY_HOUR'].dt.time

# %%
df['DELIVERY_DATE'] = pd.to_datetime((df['DELIVERY_DATE']))
df['DELIVERY_HOUR'] = pd.to_timedelta(df['DELIVERY_HOUR'].astype('str'))
df['DATE_HOUR'] = df['DELIVERY_DATE']+df['DELIVERY_HOUR']

# %%
df
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 0         2020-07-15 0 days 00:00:00      1LT_T2L1T  1LATRI_T2L1   6.7
# 1         2020-07-15 0 days 00:00:00      1LT_T2L2T  1LATRI_T2L2  15.8
# 2         2020-07-15 0 days 00:00:00      1_PHILEXT  1LAT_PHILEX  33.0
# 3         2020-07-15 0 days 00:00:00            AEC     1MEX_AEC   0.0
# 4         2020-07-15 0 days 00:00:00          ALECO   3DAR_ALECO  34.0
# ...              ...             ...            ...          ...   ...
# 576283    2020-10-14 0 days 23:00:00        WESMTMP   3LABO_T1L2   3.8
# 576284    2020-10-14 0 days 23:00:00        WESMTMP     3LUZ_001   0.0
# 576285    2020-10-14 0 days 23:00:00        WESMTMP  3MAKBA_T3L2  37.4
# 576286    2020-10-14 0 days 23:00:00        WESMTMP  3MLAYA_T2L2   0.0
# 576287    2020-10-14 0 days 23:00:00        ZAMECO1  1BOTOL_T1L1   3.3
#
#           PRICE           DATE_HOUR
# 0       2084.01 2020-07-15 00:00:00
# 1       2084.01 2020-07-15 00:00:00
# 2       2084.01 2020-07-15 00:00:00
# 3       2101.26 2020-07-15 00:00:00
# 4       2022.11 2020-07-15 00:00:00
# ...         ...                 ...
# 576283     1.00 2020-10-14 23:00:00
# 576284     1.00 2020-10-14 23:00:00
# 576285     1.00 2020-10-14 23:00:00
# 576286     1.01 2020-10-14 23:00:00
# 576287     1.00 2020-10-14 23:00:00
#
# [576288 rows x 7 columns]

# %%
df_fe = df.copy()

# %%
import statsmodels.api as sm
from pylab import rcParams

# %%
#sns.set(rc={'figure.figsize':(20, 8)})
#x = df[df['RESOURCE_ID']=='1BALNEO_L01']['MW'].plot(linewidth=0.5)

# %%
df_fe
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 0         2020-07-15 0 days 00:00:00      1LT_T2L1T  1LATRI_T2L1   6.7
# 1         2020-07-15 0 days 00:00:00      1LT_T2L2T  1LATRI_T2L2  15.8
# 2         2020-07-15 0 days 00:00:00      1_PHILEXT  1LAT_PHILEX  33.0
# 3         2020-07-15 0 days 00:00:00            AEC     1MEX_AEC   0.0
# 4         2020-07-15 0 days 00:00:00          ALECO   3DAR_ALECO  34.0
# ...              ...             ...            ...          ...   ...
# 576283    2020-10-14 0 days 23:00:00        WESMTMP   3LABO_T1L2   3.8
# 576284    2020-10-14 0 days 23:00:00        WESMTMP     3LUZ_001   0.0
# 576285    2020-10-14 0 days 23:00:00        WESMTMP  3MAKBA_T3L2  37.4
# 576286    2020-10-14 0 days 23:00:00        WESMTMP  3MLAYA_T2L2   0.0
# 576287    2020-10-14 0 days 23:00:00        ZAMECO1  1BOTOL_T1L1   3.3
#
#           PRICE           DATE_HOUR
# 0       2084.01 2020-07-15 00:00:00
# 1       2084.01 2020-07-15 00:00:00
# 2       2084.01 2020-07-15 00:00:00
# 3       2101.26 2020-07-15 00:00:00
# 4       2022.11 2020-07-15 00:00:00
# ...         ...                 ...
# 576283     1.00 2020-10-14 23:00:00
# 576284     1.00 2020-10-14 23:00:00
# 576285     1.00 2020-10-14 23:00:00
# 576286     1.01 2020-10-14 23:00:00
# 576287     1.00 2020-10-14 23:00:00
#
# [576288 rows x 7 columns]

# %%
#1BALNEO_L01 as RESOURCE ID
DF_1BALNEO_L01 = df_fe['RESOURCE_ID']=='1BALNEO_L01'

# %%
DF_1BALNEO_L01 = DF_1BALNEO_L01

# %%
DF_1BALNEO_L01 = df_fe.loc[df_fe['RESOURCE_ID'] == '1BALNEO_L01']

# %%
DF_1BALNEO_L01
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 50        2020-07-15 0 days 00:00:00           WESM  1BALNEO_L01  23.9
# 311       2020-07-15 0 days 01:00:00           WESM  1BALNEO_L01  22.9
# 572       2020-07-15 0 days 02:00:00           WESM  1BALNEO_L01  21.4
# 833       2020-07-15 0 days 03:00:00           WESM  1BALNEO_L01  20.4
# 1094      2020-07-15 0 days 04:00:00           WESM  1BALNEO_L01  19.3
# ...              ...             ...            ...          ...   ...
# 575033    2020-10-14 0 days 19:00:00           WESM  1BALNEO_L01  26.8
# 575294    2020-10-14 0 days 20:00:00           WESM  1BALNEO_L01  27.1
# 575555    2020-10-14 0 days 21:00:00           WESM  1BALNEO_L01  26.8
# 575816    2020-10-14 0 days 22:00:00           WESM  1BALNEO_L01  25.0
# 576077    2020-10-14 0 days 23:00:00           WESM  1BALNEO_L01  23.4
#
#           PRICE           DATE_HOUR
# 50      2052.67 2020-07-15 00:00:00
# 311     1863.61 2020-07-15 01:00:00
# 572     1697.97 2020-07-15 02:00:00
# 833     1699.55 2020-07-15 03:00:00
# 1094    1696.21 2020-07-15 04:00:00
# ...         ...                 ...
# 575033  1311.84 2020-10-14 19:00:00
# 575294  1363.32 2020-10-14 20:00:00
# 575555  1654.49 2020-10-14 21:00:00
# 575816  1280.42 2020-10-14 22:00:00
# 576077     0.99 2020-10-14 23:00:00
#
# [2208 rows x 7 columns]

# %%
DF_1BALNEO_L01 = DF_1BALNEO_L01.drop(columns=['DELIVERY_HOUR', 'PARTICIPANT_ID','RESOURCE_ID','PRICE','DATE_HOUR'])

# %%
DF_1BALNEO_L01
# Out:
#        DELIVERY_DATE    MW
# 50        2020-07-15  23.9
# 311       2020-07-15  22.9
# 572       2020-07-15  21.4
# 833       2020-07-15  20.4
# 1094      2020-07-15  19.3
# ...              ...   ...
# 575033    2020-10-14  26.8
# 575294    2020-10-14  27.1
# 575555    2020-10-14  26.8
# 575816    2020-10-14  25.0
# 576077    2020-10-14  23.4
#
# [2208 rows x 2 columns]

# %%
DF_1BALNEO_L = DF_1BALNEO_L01.set_index('DELIVERY_DATE')

# %%
DF_1BALNEO_L.index
# Out:
# DatetimeIndex(['2020-07-15', '2020-07-15', '2020-07-15', '2020-07-15',
#                '2020-07-15', '2020-07-15', '2020-07-15', '2020-07-15',
#                '2020-07-15', '2020-07-15',
#                ...
#                '2020-10-14', '2020-10-14', '2020-10-14', '2020-10-14',
#                '2020-10-14', '2020-10-14', '2020-10-14', '2020-10-14',
#                '2020-10-14', '2020-10-14'],
#               dtype='datetime64[ns]', name='DELIVERY_DATE', length=2208, freq=None)

# %%
DF_1BALNEO_L
# Out:
#                  MW
# DELIVERY_DATE
# 2020-07-15     23.9
# 2020-07-15     22.9
# 2020-07-15     21.4
# 2020-07-15     20.4
# 2020-07-15     19.3
# ...             ...
# 2020-10-14     26.8
# 2020-10-14     27.1
# 2020-10-14     26.8
# 2020-10-14     25.0
# 2020-10-14     23.4
#
# [2208 rows x 1 columns]

# %%
DF_1BALNEO_L.plot(linewidth=0.5)
#MALI HERE
# Out:
# <AxesSubplot:xlabel='DELIVERY_DATE'>

# %%
DF_1BALNEO_L01 = df_fe['RESOURCE_ID']=='1BALNEO_L01'
DF_1BALNEO_L01 = DF_1BALNEO_L01
DF_1BALNEO_L01 = df_fe.loc[df_fe['RESOURCE_ID'] == '1BALNEO_L01']
DF_1BALNEO_L01
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 50        2020-07-15 0 days 00:00:00           WESM  1BALNEO_L01  23.9
# 311       2020-07-15 0 days 01:00:00           WESM  1BALNEO_L01  22.9
# 572       2020-07-15 0 days 02:00:00           WESM  1BALNEO_L01  21.4
# 833       2020-07-15 0 days 03:00:00           WESM  1BALNEO_L01  20.4
# 1094      2020-07-15 0 days 04:00:00           WESM  1BALNEO_L01  19.3
# ...              ...             ...            ...          ...   ...
# 575033    2020-10-14 0 days 19:00:00           WESM  1BALNEO_L01  26.8
# 575294    2020-10-14 0 days 20:00:00           WESM  1BALNEO_L01  27.1
# 575555    2020-10-14 0 days 21:00:00           WESM  1BALNEO_L01  26.8
# 575816    2020-10-14 0 days 22:00:00           WESM  1BALNEO_L01  25.0
# 576077    2020-10-14 0 days 23:00:00           WESM  1BALNEO_L01  23.4
#
#           PRICE           DATE_HOUR
# 50      2052.67 2020-07-15 00:00:00
# 311     1863.61 2020-07-15 01:00:00
# 572     1697.97 2020-07-15 02:00:00
# 833     1699.55 2020-07-15 03:00:00
# 1094    1696.21 2020-07-15 04:00:00
# ...         ...                 ...
# 575033  1311.84 2020-10-14 19:00:00
# 575294  1363.32 2020-10-14 20:00:00
# 575555  1654.49 2020-10-14 21:00:00
# 575816  1280.42 2020-10-14 22:00:00
# 576077     0.99 2020-10-14 23:00:00
#
# [2208 rows x 7 columns]

# %%
DF_1BALNEO_L01 = DF_1BALNEO_L01.drop(columns=['DELIVERY_DATE','DELIVERY_HOUR', 'PARTICIPANT_ID','RESOURCE_ID','PRICE'])

# %%
DF_1BALNEO_L01
# Out:
#           MW           DATE_HOUR
# 50      23.9 2020-07-15 00:00:00
# 311     22.9 2020-07-15 01:00:00
# 572     21.4 2020-07-15 02:00:00
# 833     20.4 2020-07-15 03:00:00
# 1094    19.3 2020-07-15 04:00:00
# ...      ...                 ...
# 575033  26.8 2020-10-14 19:00:00
# 575294  27.1 2020-10-14 20:00:00
# 575555  26.8 2020-10-14 21:00:00
# 575816  25.0 2020-10-14 22:00:00
# 576077  23.4 2020-10-14 23:00:00
#
# [2208 rows x 2 columns]

# %%
DF_1BALNEO_L = DF_1BALNEO_L01.set_index('DATE_HOUR')

# %%
DF_1BALNEO_L
# Out:
#                        MW
# DATE_HOUR
# 2020-07-15 00:00:00  23.9
# 2020-07-15 01:00:00  22.9
# 2020-07-15 02:00:00  21.4
# 2020-07-15 03:00:00  20.4
# 2020-07-15 04:00:00  19.3
# ...                   ...
# 2020-10-14 19:00:00  26.8
# 2020-10-14 20:00:00  27.1
# 2020-10-14 21:00:00  26.8
# 2020-10-14 22:00:00  25.0
# 2020-10-14 23:00:00  23.4
#
# [2208 rows x 1 columns]

# %%
DF_1BALNEO_L.plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='DATE_HOUR'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

# %%
decomposition = sm.tsa.seasonal_decompose(DF_1BALNEO_L, model='additive')

# %%
fig = decomposition.plot()
plt.show()

# %%
import itertools

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(DF_1BALNEO_L,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            print ('AIC-order: {}' .format(res.aic_min_order))
        except:
            continue
# Out:
# ded, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:7555.417156997451
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:8920.737121373359C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
#
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:6508.999759335948
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:7557.315304070655
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:6566.229214065761
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:5318.887404861258
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:5264.384127811796
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:8560.30037559243
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:8504.120007145844
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:9747.603666185367
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:7094.393251619795
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:8490.844596514336
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:7159.481830932802
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:5296.411687526425
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:5273.265274863654
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:7603.603741368611
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:7555.239414512144
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:8808.391049110887
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:6412.658728360706
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:7554.035235057745
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:6476.1704372098775
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:5238.038294152955
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:5199.614885018305
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:7553.213236059844
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:7510.604922882548
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:8894.889713297656
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:6447.899600464162
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:7505.701940981946
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:6507.584632604554
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:5312.637698438681
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:5258.889264677133
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:7427.944882788937
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:7386.776016233171
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:8829.06780450444
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:6426.862879500961
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:7388.818148958933
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:6485.828442293408
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:5311.739051879595
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:5258.398018002459

# %%
mod = sm.tsa.statespace.SARIMAX(y,order=(1, 1, 1),seasonal_order=(1, 1, 1, 12),enforce_stationarity=False,enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-0badc6747dea> in <module>
# ----> 1 mod = sm.tsa.statespace.SARIMAX(y,order=(1, 1, 1),seasonal_order=(1, 1, 1, 12),enforce_stationarity=False,enforce_invertibility=False)
#       2 results = mod.fit()
#       3 print(results.summary().tables[1])
#
# NameError: name 'y' is not defined

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-148-6cfeaa52b7c1> in <module>
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize)
#    3901             x = np.arange(len(resid))
#    3902         ax.plot(x, resid)
# -> 3903         ax.hlines(0, x[0], x[-1], alpha=0.5)
#    3904         ax.set_xlim(x[0], x[-1])
#    3905         ax.set_title('Standardized residual')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-07-15 00:00:00'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2020':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('DATE_HOUR')
ax.set_ylabel('MW')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1594771200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2020-07-15 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     624         try:
# --> 625             return Index.get_loc(self, key, method, tolerance)
#     626         except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#
# KeyError: Timestamp('2020-07-15 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     527         try:
# --> 528             start, start_index, start_oos = self._get_index_label_loc(start)
#     529         except KeyError:
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_index_label_loc(self, key, base_index)
#     464             except:
# --> 465                 raise e
#     466         return loc, index, index_was_expanded
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_index_label_loc(self, key, base_index)
#     428             loc, index, index_was_expanded = (
# --> 429                 self._get_index_loc(key, base_index))
#     430         except KeyError as e:
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_index_loc(self, key, base_index)
#     362             # (note that get_loc will throw a KeyError if key is invalid)
# --> 363             loc = index.get_loc(key)
#     364         elif int_index or range_index:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     626         except KeyError as err:
# --> 627             raise KeyError(orig_key) from err
#     628
#
# KeyError: Timestamp('2020-07-15 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-76118103c051> in <module>
# ----> 1 pred = results.get_prediction(start=pd.to_datetime('2020-07-15 00:00:00'), dynamic=False)
#       2 pred_ci = pred.conf_int()
#       3 ax = y['2020':].plot(label='observed')
#       4 pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
#       5 ax.fill_between(pred_ci.index,
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3217         # Handle start, end, dynamic
#    3218         start, end, out_of_sample, prediction_index = (
# -> 3219             self.model._get_prediction_index(start, end, index))
#    3220
#    3221         # Handle `dynamic`
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     528             start, start_index, start_oos = self._get_index_label_loc(start)
#     529         except KeyError:
# --> 530             raise KeyError('The `start` argument could not be matched to a'
#     531                            ' location related to the index of the data.')
#     532         if end is None:
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'

# %%
df_fe
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 0         2020-07-15 0 days 00:00:00      1LT_T2L1T  1LATRI_T2L1   6.7
# 1         2020-07-15 0 days 00:00:00      1LT_T2L2T  1LATRI_T2L2  15.8
# 2         2020-07-15 0 days 00:00:00      1_PHILEXT  1LAT_PHILEX  33.0
# 3         2020-07-15 0 days 00:00:00            AEC     1MEX_AEC   0.0
# 4         2020-07-15 0 days 00:00:00          ALECO   3DAR_ALECO  34.0
# ...              ...             ...            ...          ...   ...
# 576283    2020-10-14 0 days 23:00:00        WESMTMP   3LABO_T1L2   3.8
# 576284    2020-10-14 0 days 23:00:00        WESMTMP     3LUZ_001   0.0
# 576285    2020-10-14 0 days 23:00:00        WESMTMP  3MAKBA_T3L2  37.4
# 576286    2020-10-14 0 days 23:00:00        WESMTMP  3MLAYA_T2L2   0.0
# 576287    2020-10-14 0 days 23:00:00        ZAMECO1  1BOTOL_T1L1   3.3
#
#           PRICE           DATE_HOUR
# 0       2084.01 2020-07-15 00:00:00
# 1       2084.01 2020-07-15 00:00:00
# 2       2084.01 2020-07-15 00:00:00
# 3       2101.26 2020-07-15 00:00:00
# 4       2022.11 2020-07-15 00:00:00
# ...         ...                 ...
# 576283     1.00 2020-10-14 23:00:00
# 576284     1.00 2020-10-14 23:00:00
# 576285     1.00 2020-10-14 23:00:00
# 576286     1.01 2020-10-14 23:00:00
# 576287     1.00 2020-10-14 23:00:00
#
# [576288 rows x 7 columns]

# %%
#2PACO_T1L1

# %%
DF_2PACO_T1L1 = df_fe['RESOURCE_ID']=='2PACO_T1L1'
DF_2PACO_T1L1 = df_fe.loc[df_fe['RESOURCE_ID'] == '2PACO_T1L1']
DF_2PACO_T1L1
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID RESOURCE_ID     MW  \
# 26        2020-07-15 0 days 00:00:00        MERALCO  2PACO_T1L1  371.9
# 287       2020-07-15 0 days 01:00:00        MERALCO  2PACO_T1L1  360.3
# 548       2020-07-15 0 days 02:00:00        MERALCO  2PACO_T1L1  353.6
# 809       2020-07-15 0 days 03:00:00        MERALCO  2PACO_T1L1  344.8
# 1070      2020-07-15 0 days 04:00:00        MERALCO  2PACO_T1L1  337.8
# ...              ...             ...            ...         ...    ...
# 575009    2020-10-14 0 days 19:00:00        MERALCO  2PACO_T1L1  348.3
# 575270    2020-10-14 0 days 20:00:00        MERALCO  2PACO_T1L1  343.0
# 575531    2020-10-14 0 days 21:00:00        MERALCO  2PACO_T1L1  318.2
# 575792    2020-10-14 0 days 22:00:00        MERALCO  2PACO_T1L1  313.0
# 576053    2020-10-14 0 days 23:00:00        MERALCO  2PACO_T1L1  314.7
#
#           PRICE           DATE_HOUR
# 26      2115.13 2020-07-15 00:00:00
# 287     1912.02 2020-07-15 01:00:00
# 548     1731.19 2020-07-15 02:00:00
# 809     1730.16 2020-07-15 03:00:00
# 1070    1726.71 2020-07-15 04:00:00
# ...         ...                 ...
# 575009  1338.22 2020-10-14 19:00:00
# 575270  1389.94 2020-10-14 20:00:00
# 575531  1695.01 2020-10-14 21:00:00
# 575792  1309.03 2020-10-14 22:00:00
# 576053     1.02 2020-10-14 23:00:00
#
# [2208 rows x 7 columns]

# %%
DF_2PACO_T1L1 = DF_2PACO_T1L1.drop(columns=['DELIVERY_DATE','DELIVERY_HOUR', 'PARTICIPANT_ID','RESOURCE_ID','PRICE'])

# %%
DF_2PACO_T1L1 = DF_2PACO_T1L1.set_index('DATE_HOUR')

# %%
DF_2PACO_T1L1
# Out:
#                         MW
# DATE_HOUR
# 2020-07-15 00:00:00  371.9
# 2020-07-15 01:00:00  360.3
# 2020-07-15 02:00:00  353.6
# 2020-07-15 03:00:00  344.8
# 2020-07-15 04:00:00  337.8
# ...                    ...
# 2020-10-14 19:00:00  348.3
# 2020-10-14 20:00:00  343.0
# 2020-10-14 21:00:00  318.2
# 2020-10-14 22:00:00  313.0
# 2020-10-14 23:00:00  314.7
#
# [2208 rows x 1 columns]

# %%
DF_2PACO_T1L1.plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='DATE_HOUR'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

# %%
decomposition = sm.tsa.seasonal_decompose(DF_1BALNEO_L, model='additive')

# %%
fig = decomposition.plot()
plt.show()

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(DF_1BALNEO_L,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            print ('AIC-order: {}' .format(res.aic_min_order))
        except:
            continue
# Out:
# nda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:7555.417156997451
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:8920.737121373359C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
#
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:6508.999759335948
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:7557.315304070655
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:6566.229214065761
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:5318.887404861258
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:5264.384127811796
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:8560.30037559243
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:8504.120007145844
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:9747.603666185367
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:7094.393251619795
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:8490.844596514336
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:7159.481830932802
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:5296.411687526425
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:5273.265274863654
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:7603.603741368611
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:7555.239414512144
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:8808.391049110887
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:6412.658728360706
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:7554.035235057745
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:6476.1704372098775
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:5238.038294152955
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:5199.614885018305
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:7553.213236059844
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:7510.604922882548
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:8894.889713297656
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:6447.899600464162
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:7505.701940981946C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
#
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:6507.584632604554
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:5312.637698438681
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:7427.944882788937C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
#
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:7386.776016233171
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:8829.06780450444
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:6426.862879500961
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:7388.818148958933
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:5311.739051879595
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:5258.398018002459

# %%
mod = sm.tsa.statespace.SARIMAX(y,order=(1, 1, 0),seasonal_order=(0, 1, 1, 12),enforce_stationarity=False,enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1               0         -0        nan        nan           0           0
# ma.S.L12            0         -0        nan        nan           0           0
# sigma2         1.0000         -0       -inf      0.000       1.000       1.000
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-174-6cfeaa52b7c1> in <module>
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize)
#    3901             x = np.arange(len(resid))
#    3902         ax.plot(x, resid)
# -> 3903         ax.hlines(0, x[0], x[-1], alpha=0.5)
#    3904         ax.set_xlim(x[0], x[-1])
#    3905         ax.set_title('Standardized residual')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df_orig
# Out:
#        DELIVERY_DATE  DELIVERY_HOUR REGION_ID TYPE_ID PARTICIPANT_ID  \
# 0          7/15/2020              1     LUZON      LD      1LT_T2L1T
# 1          7/15/2020              1     LUZON      LD      1LT_T2L2T
# 2          7/15/2020              1     LUZON      LD      1_PHILEXT
# 3          7/15/2020              1     LUZON      LD            AEC
# 4          7/15/2020              1     LUZON      LD          ALECO
# ...              ...            ...       ...     ...            ...
# 576283    10/14/2020             24     LUZON      LD        WESMTMP
# 576284    10/14/2020             24     LUZON      LD        WESMTMP
# 576285    10/14/2020             24     LUZON      LD        WESMTMP
# 576286    10/14/2020             24     LUZON      LD        WESMTMP
# 576287    10/14/2020             24     LUZON      LD        ZAMECO1
#
#         RESOURCE_ID    MW    PRICE
# 0       1LATRI_T2L1   6.7  2084.01
# 1       1LATRI_T2L2  15.8  2084.01
# 2       1LAT_PHILEX  33.0  2084.01
# 3          1MEX_AEC   0.0  2101.26
# 4        3DAR_ALECO  34.0  2022.11
# ...             ...   ...      ...
# 576283   3LABO_T1L2   3.8     1.00
# 576284     3LUZ_001   0.0     1.00
# 576285  3MAKBA_T3L2  37.4     1.00
# 576286  3MLAYA_T2L2   0.0     1.01
# 576287  1BOTOL_T1L1   3.3     1.00
#
# [576288 rows x 8 columns]

# %%
df.head()
# Out:
#   DELIVERY_DATE DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW    PRICE  \
# 0    2020-07-15        0 days      1LT_T2L1T  1LATRI_T2L1   6.7  2084.01
# 1    2020-07-15        0 days      1LT_T2L2T  1LATRI_T2L2  15.8  2084.01
# 2    2020-07-15        0 days      1_PHILEXT  1LAT_PHILEX  33.0  2084.01
# 3    2020-07-15        0 days            AEC     1MEX_AEC   0.0  2101.26
# 4    2020-07-15        0 days          ALECO   3DAR_ALECO  34.0  2022.11
#
#    DATE_HOUR
# 0 2020-07-15
# 1 2020-07-15
# 2 2020-07-15
# 3 2020-07-15
# 4 2020-07-15

# %%
df.groupby(df['DELIVERY_DATE'].dt.date)

# %%
df
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 0         2020-07-15 0 days 00:00:00      1LT_T2L1T  1LATRI_T2L1   6.7
# 1         2020-07-15 0 days 00:00:00      1LT_T2L2T  1LATRI_T2L2  15.8
# 2         2020-07-15 0 days 00:00:00      1_PHILEXT  1LAT_PHILEX  33.0
# 3         2020-07-15 0 days 00:00:00            AEC     1MEX_AEC   0.0
# 4         2020-07-15 0 days 00:00:00          ALECO   3DAR_ALECO  34.0
# ...              ...             ...            ...          ...   ...
# 576283    2020-10-14 0 days 23:00:00        WESMTMP   3LABO_T1L2   3.8
# 576284    2020-10-14 0 days 23:00:00        WESMTMP     3LUZ_001   0.0
# 576285    2020-10-14 0 days 23:00:00        WESMTMP  3MAKBA_T3L2  37.4
# 576286    2020-10-14 0 days 23:00:00        WESMTMP  3MLAYA_T2L2   0.0
# 576287    2020-10-14 0 days 23:00:00        ZAMECO1  1BOTOL_T1L1   3.3
#
#           PRICE           DATE_HOUR
# 0       2084.01 2020-07-15 00:00:00
# 1       2084.01 2020-07-15 00:00:00
# 2       2084.01 2020-07-15 00:00:00
# 3       2101.26 2020-07-15 00:00:00
# 4       2022.11 2020-07-15 00:00:00
# ...         ...                 ...
# 576283     1.00 2020-10-14 23:00:00
# 576284     1.00 2020-10-14 23:00:00
# 576285     1.00 2020-10-14 23:00:00
# 576286     1.01 2020-10-14 23:00:00
# 576287     1.00 2020-10-14 23:00:00
#
# [576288 rows x 7 columns]

# %%
df_fe
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID  RESOURCE_ID    MW  \
# 0         2020-07-15 0 days 00:00:00      1LT_T2L1T  1LATRI_T2L1   6.7
# 1         2020-07-15 0 days 00:00:00      1LT_T2L2T  1LATRI_T2L2  15.8
# 2         2020-07-15 0 days 00:00:00      1_PHILEXT  1LAT_PHILEX  33.0
# 3         2020-07-15 0 days 00:00:00            AEC     1MEX_AEC   0.0
# 4         2020-07-15 0 days 00:00:00          ALECO   3DAR_ALECO  34.0
# ...              ...             ...            ...          ...   ...
# 576283    2020-10-14 0 days 23:00:00        WESMTMP   3LABO_T1L2   3.8
# 576284    2020-10-14 0 days 23:00:00        WESMTMP     3LUZ_001   0.0
# 576285    2020-10-14 0 days 23:00:00        WESMTMP  3MAKBA_T3L2  37.4
# 576286    2020-10-14 0 days 23:00:00        WESMTMP  3MLAYA_T2L2   0.0
# 576287    2020-10-14 0 days 23:00:00        ZAMECO1  1BOTOL_T1L1   3.3
#
#           PRICE           DATE_HOUR
# 0       2084.01 2020-07-15 00:00:00
# 1       2084.01 2020-07-15 00:00:00
# 2       2084.01 2020-07-15 00:00:00
# 3       2101.26 2020-07-15 00:00:00
# 4       2022.11 2020-07-15 00:00:00
# ...         ...                 ...
# 576283     1.00 2020-10-14 23:00:00
# 576284     1.00 2020-10-14 23:00:00
# 576285     1.00 2020-10-14 23:00:00
# 576286     1.01 2020-10-14 23:00:00
# 576287     1.00 2020-10-14 23:00:00
#
# [576288 rows x 7 columns]

# %%
#DF_2PACO_T1L1

# %%
DF_2PACO_T1L1 = df_fe[df_fe['RESOURCE_ID'] == '2PACO_T1L1']

# %%
DF_2PACO_T1L1
# Out:
#        DELIVERY_DATE   DELIVERY_HOUR PARTICIPANT_ID RESOURCE_ID     MW  \
# 26        2020-07-15 0 days 00:00:00        MERALCO  2PACO_T1L1  371.9
# 287       2020-07-15 0 days 01:00:00        MERALCO  2PACO_T1L1  360.3
# 548       2020-07-15 0 days 02:00:00        MERALCO  2PACO_T1L1  353.6
# 809       2020-07-15 0 days 03:00:00        MERALCO  2PACO_T1L1  344.8
# 1070      2020-07-15 0 days 04:00:00        MERALCO  2PACO_T1L1  337.8
# ...              ...             ...            ...         ...    ...
# 575009    2020-10-14 0 days 19:00:00        MERALCO  2PACO_T1L1  348.3
# 575270    2020-10-14 0 days 20:00:00        MERALCO  2PACO_T1L1  343.0
# 575531    2020-10-14 0 days 21:00:00        MERALCO  2PACO_T1L1  318.2
# 575792    2020-10-14 0 days 22:00:00        MERALCO  2PACO_T1L1  313.0
# 576053    2020-10-14 0 days 23:00:00        MERALCO  2PACO_T1L1  314.7
#
#           PRICE           DATE_HOUR
# 26      2115.13 2020-07-15 00:00:00
# 287     1912.02 2020-07-15 01:00:00
# 548     1731.19 2020-07-15 02:00:00
# 809     1730.16 2020-07-15 03:00:00
# 1070    1726.71 2020-07-15 04:00:00
# ...         ...                 ...
# 575009  1338.22 2020-10-14 19:00:00
# 575270  1389.94 2020-10-14 20:00:00
# 575531  1695.01 2020-10-14 21:00:00
# 575792  1309.03 2020-10-14 22:00:00
# 576053     1.02 2020-10-14 23:00:00
#
# [2208 rows x 7 columns]

# %%
#Daily sum of 2PACO_T1L1
Daily2PACO_T1L1 = DF_2PACO_T1L1.groupby('DELIVERY_DATE')['MW'].agg('sum').reset_index()

# %%
Daily2PACO_T1L1
# Out:
#    DELIVERY_DATE      MW
# 0     2020-07-15  9409.4
# 1     2020-07-16  9558.5
# 2     2020-07-17  9512.6
# 3     2020-07-18  8889.5
# 4     2020-07-19  8344.2
# ..           ...     ...
# 87    2020-10-10  8546.2
# 88    2020-10-11  6826.1
# 89    2020-10-12  7965.3
# 90    2020-10-13  8616.8
# 91    2020-10-14  8128.0
#
# [92 rows x 2 columns]

# %%
Daily2PACO_T1L1.plot()
plt.show()

# %%
#Daily sum of 2PACO_T1L1
Daily2PACO_T1L1 = DF_2PACO_T1L1.groupby('DELIVERY_DATE')['MW'].agg('sum')

# %%
Daily2PACO_T1L1
# Out:
# DELIVERY_DATE
# 2020-07-15    9409.4
# 2020-07-16    9558.5
# 2020-07-17    9512.6
# 2020-07-18    8889.5
# 2020-07-19    8344.2
#                ...
# 2020-10-10    8546.2
# 2020-10-11    6826.1
# 2020-10-12    7965.3
# 2020-10-13    8616.8
# 2020-10-14    8128.0
# Name: MW, Length: 92, dtype: float64

# %%
Daily2PACO_T1L1.plot()
# Out:
# <AxesSubplot:xlabel='DELIVERY_DATE'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(Daily2PACO_T1L1, model='additive')
fig = decomposition.plot()
plt.show()

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(Daily2PACO_T1L1,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            print ('AIC-order: {}'.format(res.aic_min_order))
        except:
            continue
# Out:
# els\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1055.5377272768862
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1247.9196550267745
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1219.1596294983297
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1094.0882119130365
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1057.3303957984836
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1435.877899262388
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1247.50252097152
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1287.0798633370982
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1073.8766194622965
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1247.7090210367871
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1249.3912495827924
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:1083.327569331523
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1074.4405601366097
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1422.5561600346077
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1234.575778461162
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1264.4767625077743
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:1056.082222967067
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1249.6650854956754
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1236.3441310245912C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:1076.85586759902
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:1056.2446647965157
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1421.056378492841
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1232.8686404708092
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1286.9354525489168
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1070.533177846674C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1233.1551172919433
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1234.652720398203
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1079.0243260944555
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1072.2057082126237
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1395.1685375290297
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1205.644491588052C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1270.1490053426178
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1054.3830650583081
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1222.2585966487486
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1207.636449816309
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1075.7246169820596
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1056.2877328572752

# %%
mod = sm.tsa.statespace.SARIMAX(Daily2PACO_T1L1,order=(1, 1, 1),seasonal_order=(0, 1, 1, 12),enforce_stationarity=False,enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7811      0.111     -7.031      0.000      -0.999      -0.563
# ma.L1          0.9986      2.952      0.338      0.735      -4.787       6.784
# ma.S.L12      -0.6702      0.156     -4.308      0.000      -0.975      -0.365
# sigma2      5.097e+05   1.48e+06      0.344      0.731   -2.39e+06    3.41e+06
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
Daily2PACO_T1L1 = DF_2PACO_T1L1.groupby('DELIVERY_DATE')['MW'].agg('sum').reset_index()

# %%
Daily2PACO_T1L1.head()
# Out:
#   DELIVERY_DATE      MW
# 0    2020-07-15  9409.4
# 1    2020-07-16  9558.5
# 2    2020-07-17  9512.6
# 3    2020-07-18  8889.5
# 4    2020-07-19  8344.2

# %%
y = Daily2PACO_T1L1.set_index('DELIVERY_DATE')

# %%
y
# Out:
#                    MW
# DELIVERY_DATE
# 2020-07-15     9409.4
# 2020-07-16     9558.5
# 2020-07-17     9512.6
# 2020-07-18     8889.5
# 2020-07-19     8344.2
# ...               ...
# 2020-10-10     8546.2
# 2020-10-11     6826.1
# 2020-10-12     7965.3
# 2020-10-13     8616.8
# 2020-10-14     8128.0
#
# [92 rows x 1 columns]

# %%
y['MW'].plot()
# Out:
# <AxesSubplot:xlabel='DELIVERY_DATE'>

# %%
Daily2PACO_T1L1['MW'].plot()
# Out:
# <AxesSubplot:>

# %%
y['MW'].rolling(window=7).mean()
# Out:
# DELIVERY_DATE
# 2020-07-15            NaN
# 2020-07-16            NaN
# 2020-07-17            NaN
# 2020-07-18            NaN
# 2020-07-19            NaN
#                  ...
# 2020-10-10    8678.014286
# 2020-10-11    8497.771429
# 2020-10-12    8352.000000
# 2020-10-13    8272.171429
# 2020-10-14    8162.357143
# Name: MW, Length: 92, dtype: float64

# %%
Daily2PACO_T1L['MW'].rolling(window=7).mean()
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#          ...
# 87    8678.014286
# 88    8497.771429
# 89    8352.000000
# 90    8272.171429
# 91    8162.357143
# Name: MW, Length: 92, dtype: float64

# %%
x = Daily2PACO_T1L1['MW'].rolling(window=7).mean()

# %%
x.head(10)
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6    9198.657143
# 7    9180.314286
# 8    9153.900000
# 9    9202.471429
# Name: MW, dtype: float64

# %%
MA_Daily2PACO_T1L1 = Daily2PACO_T1L1['MW'].rolling(window=7).mean()

# %%
MA_Daily2PACO_T1L1 = MA_Daily2PACO_T1L1.dropna()

# %%
MA_Daily2PACO_T1L1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-33a7522da9ba> in <module>
# ----> 1 MA_Daily2PACO_T1L1
#
# NameError: name 'MA_Daily2PACO_T1L1' is not defined

# %%
MA_Daily2PACO_T1L1.plot()
# Out:
# <AxesSubplot:>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y, order=param, seasonal_order=param_seasonal, enforce_stationarity=False, enforce_invertibility=False)
            results = mod.fit()
print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# els\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1055.5377272768862
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1247.9196550267745
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1219.1596294983297
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1094.0882119130365
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1057.3303957984836
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1435.877899262388
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1247.50252097152
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1287.0798633370982
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1073.8766194622965
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1247.7090210367871
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1249.3912495827924
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:1083.327569331523
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1074.4405601366097
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1422.5561600346077
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1234.575778461162
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1264.4767625077743
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:1056.082222967067
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1249.6650854956754
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1236.3441310245912C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:1076.85586759902
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:1056.2446647965157
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1421.056378492841
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1232.8686404708092
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1286.9354525489168
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1070.533177846674
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1233.1551172919433
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1234.652720398203
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1079.0243260944555
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1072.2057082126237
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1395.1685375290297
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1205.644491588052
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1270.1490053426178
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1054.3830650583081
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1222.2585966487486
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1207.636449816309
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1075.7246169820596
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1056.2877328572752

# %%
#ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1057.3303957984836

# %%
mod = sm.tsa.statespace.SARIMAX(y,order=(0, 1, 1),seasonal_order=(1, 1, 1, 12),enforce_stationarity=False,enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\William\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.0062      0.118      0.052      0.958      -0.225       0.237
# ar.S.L12       0.0959      0.244      0.392      0.695      -0.383       0.575
# ma.S.L12      -0.8341      0.509     -1.639      0.101      -1.831       0.163
# sigma2      5.319e+05   1.59e+05      3.355      0.001    2.21e+05    8.43e+05
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-10-10'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2020':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('MW')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2017-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2020-10-10 00:00:00   NaN
# 2020-10-11 00:00:00   NaN
# 2020-10-12 00:00:00   NaN
# 2020-10-13 00:00:00   NaN
# 2020-10-14 00:00:00   NaN
# MW                    NaN
# dtype: float64

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 2020-10-10 00:00:00   NaN
# 2020-10-11 00:00:00   NaN
# 2020-10-12 00:00:00   NaN
# 2020-10-13 00:00:00   NaN
# 2020-10-14 00:00:00   NaN
# MW                    NaN
# dtype: float64

# %%
pred_uc = results.get_forecast(steps=20)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('MW')
plt.legend()
plt.show()
